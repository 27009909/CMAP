# %% [markdown]
# # Stage 1 - PRE PROCESSING TO SEMI PROCESSED

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pickle
from sklearn.linear_model import LinearRegression
import datetime
from datetime import datetime
from datetime import timezone

# %%
df = pd.read_csv(r'E:\CMAP_DATA\PRE_PROCESSED_DATA\WILTSHIRE_DATABASE_DATA\2018-11-wiltshire-street.csv')

# %%
df2 = pd.read_csv(r'E:\CMAP_DATA\PRE_PROCESSED_DATA\WILTSHIRE_DATABASE_DATA\2018-12-wiltshire-street.csv')
df3 = pd.read_csv(r'E:\CMAP_DATA\PRE_PROCESSED_DATA\WILTSHIRE_DATABASE_DATA\2019-01-wiltshire-street.csv')
df4 = pd.read_csv(r'E:\CMAP_DATA\PRE_PROCESSED_DATA\WILTSHIRE_DATABASE_DATA\2019-02-wiltshire-street.csv')
df5 = pd.read_csv(r'E:\CMAP_DATA\PRE_PROCESSED_DATA\WILTSHIRE_DATABASE_DATA\2019-03-wiltshire-street.csv')
df6 = pd.read_csv(r'E:\CMAP_DATA\PRE_PROCESSED_DATA\WILTSHIRE_DATABASE_DATA\2019-04-wiltshire-street.csv')
df7 = pd.read_csv(r'E:\CMAP_DATA\PRE_PROCESSED_DATA\WILTSHIRE_DATABASE_DATA\2019-05-wiltshire-street.csv')
df8 = pd.read_csv(r'E:\CMAP_DATA\PRE_PROCESSED_DATA\WILTSHIRE_DATABASE_DATA\2019-06-wiltshire-street.csv')
df9 = pd.read_csv(r'E:\CMAP_DATA\PRE_PROCESSED_DATA\WILTSHIRE_DATABASE_DATA\2019-07-wiltshire-street.csv')

df10 = pd.read_csv(r'E:\CMAP_DATA\PRE_PROCESSED_DATA\WILTSHIRE_DATABASE_DATA\2019-08-wiltshire-street.csv')
df11 = pd.read_csv(r'E:\CMAP_DATA\PRE_PROCESSED_DATA\WILTSHIRE_DATABASE_DATA\2019-09-wiltshire-street.csv')
df12 = pd.read_csv(r'E:\CMAP_DATA\PRE_PROCESSED_DATA\WILTSHIRE_DATABASE_DATA\2019-10-wiltshire-street.csv')
df13 = pd.read_csv(r'E:\CMAP_DATA\PRE_PROCESSED_DATA\WILTSHIRE_DATABASE_DATA\2019-11-wiltshire-street.csv')
df14 = pd.read_csv(r'E:\CMAP_DATA\PRE_PROCESSED_DATA\WILTSHIRE_DATABASE_DATA\2019-12-wiltshire-street.csv')
df15 = pd.read_csv(r'E:\CMAP_DATA\PRE_PROCESSED_DATA\WILTSHIRE_DATABASE_DATA\2020-01-wiltshire-street.csv')
df16 = pd.read_csv(r'E:\CMAP_DATA\PRE_PROCESSED_DATA\WILTSHIRE_DATABASE_DATA\2020-02-wiltshire-street.csv')
df17 = pd.read_csv(r'E:\CMAP_DATA\PRE_PROCESSED_DATA\WILTSHIRE_DATABASE_DATA\2020-03-wiltshire-street.csv')
df18 = pd.read_csv(r'E:\CMAP_DATA\PRE_PROCESSED_DATA\WILTSHIRE_DATABASE_DATA\2020-04-wiltshire-street.csv')
df19 = pd.read_csv(r'E:\CMAP_DATA\PRE_PROCESSED_DATA\WILTSHIRE_DATABASE_DATA\2020-05-wiltshire-street.csv')
df20 = pd.read_csv(r'E:\CMAP_DATA\PRE_PROCESSED_DATA\WILTSHIRE_DATABASE_DATA\2020-06-wiltshire-street.csv')

df21 = pd.read_csv(r'E:\CMAP_DATA\PRE_PROCESSED_DATA\WILTSHIRE_DATABASE_DATA\2020-07-wiltshire-street.csv')
df22 = pd.read_csv(r'E:\CMAP_DATA\PRE_PROCESSED_DATA\WILTSHIRE_DATABASE_DATA\2020-08-wiltshire-street.csv')
df23 = pd.read_csv(r'E:\CMAP_DATA\PRE_PROCESSED_DATA\WILTSHIRE_DATABASE_DATA\2020-09-wiltshire-street.csv')
df24 = pd.read_csv(r'E:\CMAP_DATA\PRE_PROCESSED_DATA\WILTSHIRE_DATABASE_DATA\2020-10-wiltshire-street.csv')
df25 = pd.read_csv(r'E:\CMAP_DATA\PRE_PROCESSED_DATA\WILTSHIRE_DATABASE_DATA\2020-11-wiltshire-street.csv')

# %%
df = pd.read_csv(r'E:\CMAP_DATA\PRE_PROCESSED_DATA\NORTH_YORKSHIRE_DATABASE_DATA\2020-12-north-yorkshire-street.csv')
df2 = pd.read_csv(r'E:\CMAP_DATA\PRE_PROCESSED_DATA\NORTH_YORKSHIRE_DATABASE_DATA\2021-01-north-yorkshire-street.csv')
df3 = pd.read_csv(r'E:\CMAP_DATA\PRE_PROCESSED_DATA\NORTH_YORKSHIRE_DATABASE_DATA\2021-02-north-yorkshire-street.csv')
df = df.append([df2, df3], ignore_index=True)

# %%
df = df.append([df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15, df16, df17, df18, df19, df20, df21, df22, df23, df24, df25], ignore_index=True)

# %%
df.shape
# Out:
# (17220, 12)

# %%
dfModel = df[pd.notnull(df['Latitude'])]
dfModel = dfModel[pd.notnull(dfModel['Longitude'])]
dfModel = dfModel[dfModel.Longitude != 'No Location']
dfModel
# Out:
#                                                 Crime ID    Month  \
# 0                                                    NaN  2020-12
# 1                                                    NaN  2020-12
# 2      960ca9f424bd34e8031ac86d7eb30d3a0cb2e205985e4d...  2020-12
# 3      e3586e909b7dcd5398dffeab903c0b57dbbb98eacf6503...  2020-12
# 4                                                    NaN  2020-12
# ...                                                  ...      ...
# 17156                                                NaN  2021-02
# 17157  6351a04c8dab85f8b119b69483200382aae6f90af0b8d2...  2021-02
# 17158  7c07f7e0605546f45af1d2fef6d61190c6defb26325f7b...  2021-02
# 17159                                                NaN  2021-02
# 17160                                                NaN  2021-02
#
#                   Reported by            Falls within  Longitude   Latitude  \
# 0      North Yorkshire Police  North Yorkshire Police  -1.547821  54.659987
# ...

# %%
dfModel = dfModel[['Month', 'Longitude', 'Latitude', 'Crime type']].copy()
dfModel
# Out:
#          Month  Longitude   Latitude                    Crime type
# 0      2020-12  -1.547821  54.659987         Anti-social behaviour
# 1      2020-12  -2.534714  54.145628         Anti-social behaviour
# 2      2020-12  -2.546581  54.119061  Violence and sexual offences
# 3      2020-12  -2.538231  54.120483  Violence and sexual offences
# 4      2020-12  -2.506774  54.117923         Anti-social behaviour
# ...        ...        ...        ...                           ...
# 17156  2021-02  -1.140821  53.915064         Anti-social behaviour
# 17157  2021-02  -1.147301  53.919101     Criminal damage and arson
# 17158  2021-02  -1.144401  53.911988                 Vehicle crime
# 17159  2021-02  -1.137403  53.914716         Anti-social behaviour
# 17160  2021-02  -1.131943  53.918128         Anti-social behaviour
#
# [17041 rows x 4 columns]

# %%
dfModel.to_csv(r'E:\CMAP_DATA\SEMI_PROCESSED\NORTH_YORKSHIRE_SEMI_PROCESSED\NORTH_YORKSHIRE_SEMI_PROCESSED.csv', index=False)
print('Done. EXPORTED TO -> E:\CMAP_DATA\SEMI_PROCESSED\NORTH_YORKSHIRE_SEMI_PROCESSED\NORTH_YORKSHIRE_SEMI_PROCESSED.csv')
# Out:
# Done. EXPORTED TO -> E:\CMAP_DATA\SEMI_PROCESSED\WILTSHIRE_SEMI_PROCESSED\WILTSHIRE_SEMI_PROCESSED.csv
